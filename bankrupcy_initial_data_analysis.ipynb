# %% [markdown]
# inspired in youtube videos: "Advance House Price Prediction- Exploratory Data Analysis", "Beginner Kaggle Data Science Project Walk-Through (Titanic)", and book "Hands-On Machine LEarning with... Aurelien Geron"

# %% [markdown]
# # Bankrupcy initial data analysis

# %% [markdown]
# ### Import libraries and data

# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd, numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Mounted at /content/drive

# %%
bankrupcy_file_path = "/content/drive/My Drive/Colab Notebooks/Mini Project 1 ECSE 551 Team 2/bankrupcy.csv"
df_data = pd.read_csv(bankrupcy_file_path)
# %matplotlib inline

# %% [markdown]
# ### 1. Preliminary Data Analysis

# %% [markdown]
# ####1.1 Shape, head, columns, info, describe

# %%
df_data.shape
# Out:
# (453, 65)

# %%
df_data.head()
# Out:
#    attribute1  attribute2  attribute3  ...  attribute63  attribute64  ClassLabel
# 0     -0.0315     -0.0913     -0.0403  ...      -0.1740      -0.0468           0
# 1     -0.2320     -0.0494      0.3040  ...      -0.0731      -0.0272           0
# 2     -0.0586      0.0651     -0.4880  ...      -0.2920      -0.0336           0
# 3     -0.0694      0.0446     -0.1820  ...      -0.5550      -0.0468           0
# 4      0.2360     -0.0519      0.6780  ...      -0.0278      -0.0237           0
#
# [5 rows x 65 columns]

# %%
df_data.columns
# Out:
# Index(['attribute1', 'attribute2', 'attribute3', 'attribute4', 'attribute5',
#        'attribute6', 'attribute7', 'attribute8', 'attribute9', 'attribute10',
#        'attribute11', 'attribute12', 'attribute13', 'attribute14',
#        'attribute15', 'attribute16', 'attribute17', 'attribute18',
#        'attribute19', 'attribute20', 'attribute21', 'attribute22',
#        'attribute23', 'attribute24', 'attribute25', 'attribute26',
#        'attribute27', 'attribute28', 'attribute29', 'attribute30',
#        'attribute31', 'attribute32', 'attribute33', 'attribute34',
#        'attribute35', 'attribute36', 'attribute37', 'attribute38',
#        'attribute39', 'attribute40', 'attribute41', 'attribute42',
#        'attribute43', 'attribute44', 'attribute45', 'attribute46',
#        'attribute47', 'attribute48', 'attribute49', 'attribute50',
#        'attribute51', 'attribute52', 'attribute53', 'attribute54',
#        'attribute55', 'attribute56', 'attribute57', 'attribute58',
#        'attribute59', 'attribute60', 'attribute61', 'attribute62',
#        'attribute63', 'attribute64', 'ClassLabel'],
#       dtype='object')

# %%
#Quick look at data types and no-null values
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 453 entries, 0 to 452
# Data columns (total 65 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   attribute1   453 non-null    float64
#  1   attribute2   453 non-null    float64
#  2   attribute3   453 non-null    float64
#  3   attribute4   453 non-null    float64
#  4   attribute5   453 non-null    float64
#  5   attribute6   453 non-null    float64
#  6   attribute7   453 non-null    float64
#  7   attribute8   453 non-null    float64
#  8   attribute9   453 non-null    float64
#  9   attribute10  453 non-null    float64
#  10  attribute11  453 non-null    float64
#  11  attribute12  453 non-null    float64
#  12  attribute13  453 non-null    float64
#  13  attribute14  453 non-null    float64
#  14  attribute15  453 non-null    float64
#  15  attribute16  453 non-null    float64
#  16  attribute17  453 non-null    float64
#  17  attribute18  453 non-null    float64
#  18  attribute19  453 non-null    float64
#  19  attribute20  453 non-null    float64
#  20  attribute21  453 non-null    float64
#  21  attribute22  453 non-null    float64
#  22  attribute23  453 non-null    float64
#  23  attribute24  453 non-null    float64
#  24  attribute25  453 non-null    float64
#  25  attribute26  453 non-null    float64
#  26  attribute27  453 non-null    float64
#  27  attribute28  453 non-null    float64
#  28  attribute29  453 non-null    float64
#  29  attribute30  453 non-null    float64
#  30  attribute31  453 non-null    float64
#  31  attribute32  453 non-null    float64
#  32  attribute33  453 non-null    float64
#  33  attribute34  453 non-null    float64
#  34  attribute35  453 non-null    float64
#  35  attribute36  453 non-null    float64
#  36  attribute37  453 non-null    float64
#  37  attribute38  453 non-null    float64
#  38  attribute39  453 non-null    float64
#  39  attribute40  453 non-null    float64
#  40  attribute41  453 non-null    float64
#  41  attribute42  453 non-null    float64
#  42  attribute43  453 non-null    float64
#  43  attribute44  453 non-null    float64
#  44  attribute45  453 non-null    float64
#  45  attribute46  453 non-null    float64
#  46  attribute47  453 non-null    float64
#  47  attribute48  453 non-null    float64
#  48  attribute49  453 non-null    float64
#  49  attribute50  453 non-null    float64
#  50  attribute51  453 non-null    float64
#  51  attribute52  453 non-null    float64
#  52  attribute53  453 non-null    float64
#  53  attribute54  453 non-null    float64
#  54  attribute55  453 non-null    float64
#  55  attribute56  453 non-null    float64
#  56  attribute57  453 non-null    float64
#  57  attribute58  453 non-null    float64
#  58  attribute59  453 non-null    float64
#  59  attribute60  453 non-null    float64
#  60  attribute61  453 non-null    float64
#  61  attribute62  453 non-null    float64
#  62  attribute63  453 non-null    float64
#  63  attribute64  453 non-null    float64
#  64  ClassLabel   453 non-null    int64
# dtypes: float64(64), int64(1)
# memory usage: 230.2 KB

# %%
# Info on the numeric data with the describe() method
df_data.describe()
# Out:
#        attribute1  attribute2  attribute3  ...  attribute63  attribute64  ClassLabel
# count  453.000000  453.000000  453.000000  ...   453.000000   453.000000  453.000000
# mean    -0.079329    0.034849   -0.228204  ...    -0.120022    -0.004343    0.448124
# std      0.252813    0.101913    1.032602  ...     0.534885     0.205593    0.497851
# min     -2.250000   -0.159000   -5.990000  ...    -0.743000    -0.051000    0.000000
# 25%     -0.140000   -0.030600   -0.799000  ...    -0.436000    -0.042000    0.000000
# 50%     -0.062000    0.031500   -0.182000  ...    -0.260000    -0.035300    0.000000
# 75%      0.029600    0.083900    0.422000  ...    -0.013500    -0.021000    1.000000
# max      1.010000    0.706000    2.370000  ...     3.400000     3.980000    1.000000
#
# [8 rows x 65 columns]

# %% [markdown]
# #### 1.1 Features classification : continuous and discrete

# %%
# Separate the features into continous and discrete

discrete_features = [ feature for feature in df_data if len(df_data[feature].unique()) < 25]
#drop Class Label, which is the target
discrete_features = discrete_features[:-1]
continuous_features = [feature for feature in df_data if feature not in discrete_features + ['ClassLabel']]

# All of them are continuous

# %% [markdown]
# ### 3. Continuous Features Analysis

# %% [markdown]
# #### 3.1 Histograms

# %%
 # distribution of continuous_features
df_data[continuous_features].hist(bins=50,figsize=(30,30))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f883d91f0f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883d87d7f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883d82ca58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883d85fcc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883d814f28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883d7d41d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883d786438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883d739668>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f883d7396d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883d721b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883d6d3dd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883d697080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883d6472e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883d5fc550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883d5ae7b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883d5e0a20>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f883d595c88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883d549ef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883d509198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883d4bc400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883d470668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883d4a28d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883d456b38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883d814748>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f883d6ea390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883d556160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883d39e0f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883d351358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883d3035c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883d2b7828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883d2eaa90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883d29fcf8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f883d252f60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883d211208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883d1c6470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883d1796d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883d12c940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883d15fba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883d115e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883d0d30b8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f883d086320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883d038588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883cfed7f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883d021a58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883cfd3cc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883cf8af28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883cf461d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883cefb438>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f883ceae6a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883cee1908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883ce94b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883ce47dd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883ce09080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883cdb0c88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883cde6fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883cda33c8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f883cd54748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883cd08ac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883ccb8e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883cc76208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883cca9588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883cc58908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883cc0cc88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883cbbefd0>]],
#       dtype=object)

# %%
# Final discussion: some of the features are skewed and far from gaussian distribution
# Proposal: use their logarithms or some kind of normalization instead
# Proposal: use standarization!

# %% [markdown]
# #### 3.2 Box Plots

# %%
# Are there outliers in the continous features?
for feature in continuous_features:
  data = df_data.copy()
  if 0 in data[feature].unique():
    pass
  else:
    data[feature] = np.log(data[feature])
    data.boxplot(column=feature)
    plt.ylabel(feature)
    plt.title(feature)
    plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
# All features have outliers, but it is not worth it remove all of them
# By making standarization, we can be much less affected by outliers!!!

# %% [markdown]
# #### 3.3 Correlations

# %%
#Now let's look at correlations
corr_matrix = df_data[continuous_features+ ['ClassLabel']].corr()
print(corr_matrix)
sns.heatmap(corr_matrix)
# Out:
#              attribute1  attribute2  ...  attribute64  ClassLabel
# attribute1     1.000000   -0.368068  ...     0.002298   -0.275046
# attribute2    -0.368068    1.000000  ...     0.087644    0.323921
# attribute3     0.336251   -0.632313  ...     0.093876   -0.267652
# attribute4     0.265596   -0.453199  ...     0.000279   -0.271784
# attribute5     0.030680   -0.044202  ...     0.000093   -0.049772
# ...                 ...         ...  ...          ...         ...
# attribute61    0.023171    0.052133  ...    -0.027026    0.000254
# attribute62   -0.012462    0.014649  ...    -0.010712   -0.035863
# attribute63    0.358401   -0.447783  ...     0.001096   -0.268469
# attribute64    0.002298    0.087644  ...     1.000000    0.092562
# ClassLabel    -0.275046    0.323921  ...     0.092562    1.000000
#
# [65 rows x 65 columns]

# %%
#Because  we are using regression, we want to avoid multi colinearity (two variables highly correlated).

# %%
corr_matrix['ClassLabel'].sort_values(ascending= False)
# Out:
# ClassLabel     1.000000
# attribute2     0.323921
# attribute51    0.280592
# attribute34    0.137470
# attribute9     0.126993
#                  ...
# attribute46   -0.280750
# attribute16   -0.283008
# attribute10   -0.296351
# attribute38   -0.297520
# attribute25   -0.349247
# Name: ClassLabel, Length: 65, dtype: float64

# %%
#Can easil see that albumin and bilirubin have strong effect on the class label

# %% [markdown]
# #### 3.5 Pivot table

# %%
# Compare 'Class label' across the numeric features
pd.pivot_table(df_data, index='ClassLabel', values = continuous_features)
# Out:
#             attribute1  attribute10  ...  attribute8  attribute9
# ClassLabel                           ...
# 0            -0.016739    -0.004424  ...    0.014461   -0.029544
# 1            -0.156410    -0.079750  ...   -0.324194    0.214077
#
# [2 rows x 64 columns]

# %%
# We start seeing that younger people have more probability for 1, also those with more albumin, less alk_phosphate, much les bilirubin, more protime and less sgot.

# %% [markdown]
# ### Final thoughts

# %% [markdown]
# - Many features are tail heavy: use their logarithms
# - Many different scales: use standarization!!!
# - There are a couple of figures that are highly correlated with the target variable
# - Try to combine some of the features to gain higher correlations with the target!!

# %%
def logarithm_transformer (data_frame):
  data= data_frame.copy()
  continuous_features = [ feature for feature in data if len(data[feature].unique()) > 25]
  print(continuous_features)
  for feature in continuous_features:
    if 0 in data[feature].unique():
      print(0)
    else:
      data[feature] = np.log(data[feature])
  return data

# %%
log_transformed_df = logarithm_transformer(df_data)
log_transformed_df[continuous_features].hist(figsize=(30,30))
# Out:
# ['attribute1', 'attribute2', 'attribute3', 'attribute4', 'attribute5', 'attribute6', 'attribute7', 'attribute8', 'attribute9', 'attribute10', 'attribute11', 'attribute12', 'attribute13', 'attribute14', 'attribute15', 'attribute16', 'attribute17', 'attribute18', 'attribute19', 'attribute20', 'attribute21', 'attribute22', 'attribute23', 'attribute24', 'attribute25', 'attribute26', 'attribute27', 'attribute28', 'attribute29', 'attribute30', 'attribute31', 'attribute32', 'attribute33', 'attribute34', 'attribute35', 'attribute36', 'attribute37', 'attribute38', 'attribute39', 'attribute40', 'attribute41', 'attribute42', 'attribute43', 'attribute44', 'attribute45', 'attribute46', 'attribute47', 'attribute48', 'attribute49', 'attribute50', 'attribute51', 'attribute52', 'attribute53', 'attribute54', 'attribute55', 'attribute56', 'attribute57', 'attribute58', 'attribute59', 'attribute60', 'attribute61', 'attribute62', 'attribute63', 'attribute64']
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f883824e358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883760c2e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8837a59630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f88379f99b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f88378ced30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8837ae60f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8837df6470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8837dfd7b8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f8837dfd828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f88379bfef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883817c2b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8837fa6630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f88378159b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f88377f5d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f88378940f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8837efc470>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f8837bf07f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8837d07b38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8837cdee80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8837cb7240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8837c465c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8837bb7940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8837b7ccc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f88378ee080>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f88380a3400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f88380a7780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f88382b0b00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8838200e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8838115240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8837e225c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8837f8c940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8837f7b5f8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f8837f33080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8837c68400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8837e74780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8837dd5b00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883825de80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883829b240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f88381cd5c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883813f940>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f8838071cc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8838031048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8837fe2400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8838012780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8837ec6b00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8837d3ae80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8837b38240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8837aaa5c0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f8837a5c940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8837a8dcc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883414c048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f88340fc400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f88375fe7f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883779a1d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8837747978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f88377049e8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f8839b069b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883758bac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f88374c3e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883b68fda0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883cb1a4e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883a974b00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883a89f240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883a8e8be0>]],
#       dtype=object)

# %% [markdown]
# #### 4.2 Standarize the data

# %%
def standard_scaler(data_frame):
  data= data_frame.copy()
  continuous_features = [ feature for feature in data if len(data[feature].unique()) > 25]
  for feature in continuous_features:
    data[feature] = data[feature] - np.mean(data[feature])
    data[feature] = data[feature] / np.std(data[feature])
  return data

# %%
std_log_transformed_df = standard_scaler(log_transformed_df)
std_log_transformed_df[continuous_features].hist(bins=30, figsize=(30,30))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f883c3e3a20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8833ee1cc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f88335677b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883351ab38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883353eeb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f88334e2278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f88335085f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f88334bc940>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f88334bc9b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883342e0b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f88333df438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f88334107b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f88333c3b38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8833376eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8833334278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f88332e55f8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f8833299978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f88332c9cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883328a0b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883323d438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f88331ed7b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f88331a0b38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f88331d2eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8833190278>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f88331415f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f88330f3978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f88330a8cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f88330650b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8833019438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f88330497b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8832ffbb38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8832faeeb8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f8832f6d278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8832f215f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8832f51978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8832f05cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8832ec30b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8832e74438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8832e267b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8832dd8b38>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f8832e0beb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8832dc9278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8832d7c5f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8832d2e978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8832cdfcf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8832ca20b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8832cd2438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8832c857b8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f8832c35b38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8832be7eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8832ba6278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8832b585f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8832b89978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8832b3bcf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8832afb0b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8832aae438>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f8832a5f7b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8832a92b38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8832a44eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8832a04278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f88329b55f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8832964978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f883291bcf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f88329570b8>]],
#       dtype=object)

# %% [markdown]
# #### 4.3 Look for new features

# %%
# after the processing is done, we'll look for new features
